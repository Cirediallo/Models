# %% [markdown]
# <a href="https://colab.research.google.com/github/Cirediallo/Models/blob/main/fairseq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install transformers
# !pip install datasets
# !pip install torchaudio
# !pip install torch
# !pip install sentencepiece
# !pip install librosa
# !pip install jiwer
# !pip install evaluate
! pip install accelerate

! pip install git+https://github.com/huggingface/transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 13.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 4.1 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.9.2-1).
# 0 upgraded, 0 newly installed, 0 to remove and 24 not upgraded.

# %%
! git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 137459, done.
# remote: Counting objects: 100% (1206/1206), done.
# remote: Compressing objects: 100% (599/599), done.
# remote: Total 137459 (delta 732), reused 895 (delta 525), pack-reused 136253
# Receiving objects: 100% (137459/137459), 136.97 MiB | 34.90 MiB/s, done.
# Resolving deltas: 100% (102933/102933), done.

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
! python /content/transformers/examples/pytorch/speech-recognition/run_speech_recognition_ctc.py \
	--dataset_name="common_voice" \
	--model_name_or_path="facebook/wav2vec2-large-xlsr-53" \
	--dataset_config_name="fr" \
	--output_dir="./wav2vec2-common_voice-fr-training" \
	--overwrite_output_dir \
	--num_train_epochs="15" \
	--per_device_train_batch_size="16" \
	--gradient_accumulation_steps="2" \
	--learning_rate="3e-4" \
	--warmup_steps="500" \
	--evaluation_strategy="steps" \
	--text_column_name="sentence" \
	--length_column_name="input_length" \
	--save_steps="400" \
	--eval_steps="100" \
	--layerdrop="0.0" \
	--save_total_limit="3" \
	--freeze_feature_encoder \
	--gradient_checkpointing \
	--group_by_length \
	--push_to_hub \
	--do_train --do_eval
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#  45% 891/1971 [1:14:59<1:39:12,  5.51s/it]
#  45% 892/1971 [1:15:03<1:34:19,  5.25s/it]
#  45% 893/1971 [1:15:08<1:30:26,  5.03s/it]
#  45% 894/1971 [1:15:15<1:41:47,  5.67s/it]
#  45% 895/1971 [1:15:21<1:41:51,  5.68s/it]
#  45% 896/1971 [1:15:27<1:47:08,  5.98s/it]
#  46% 897/1971 [1:15:32<1:40:30,  5.61s/it]
#  46% 898/1971 [1:15:40<1:50:07,  6.16s/it]
#  46% 899/1971 [1:15:45<1:48:45,  6.09s/it]
#  46% 900/1971 [1:15:50<1:38:05,  5.50s/it]
#  46% 901/1971 [1:15:54<1:34:12,  5.28s/it]
#  46% 902/1971 [1:15:59<1:31:26,  5.13s/it]
#  46% 903/1971 [1:16:03<1:23:09,  4.67s/it]
#  46% 904/1971 [1:16:07<1:22:49,  4.66s/it]
#  46% 905/1971 [1:16:12<1:23:04,  4.68s/it]
#  46% 906/1971 [1:16:16<1:18:07,  4.40s/it]
#  46% 907/1971 [1:16:22<1:29:00,  5.02s/it]
#  46% 908/1971 [1:16:28<1:33:40,  5.29s/it]
#  46% 909/1971 [1:16:34<1:34:24,  5.33s/it]
#  46% 910/1971 [1:16:38<1:31:36,  5.18s/it]
# ...

# %%
# --fp16 \ removed bc it yield ValueError: FP16 Mixed precision training with AMP or APEX (`--fp16`) and FP16 
#half precision evaluation (`--fp16_full_eval`) can only be used on CUDA devices.
#if not on GPU devices
